# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from cp_utils.cp_dir_file_ops import define_env

if define_env() == 'SERVER':
    dir = '/home/neo/PycharmProjects/Course1/subprojects/sp02_omniiseg_fgn_mmdet/MNISTISEG_N3_K1'
elif define_env() == 'PC':
    dir = 'C:/Users/Art/PycharmProjects/Course1/subprojects/sp02_omniiseg_fgn_mmdet/MNISTISEG_N3_K1'
else:
    raise NotImplementedError

tag = 'MNISTISEG_val_FT_Ignore_bbox_mAP_base_'

# %%
sp0 = f'2022-02-11_22-47-44_Train-3-1-Scratch-MNISTISEG-Train LR 0.001 WD 1e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-11_22-49-46_Train-3-1-Scratch-MNISTISEG-Train LR 0.005 WD 1e-05 Adagrad-tag-{tag}.csv'
sp2 = f'2022-02-11_22-51-01_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 1e-05 Adagrad-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)
fp2 = os.path.join(dir, sp2)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)
data2 = np.around(np.loadtxt(fp2, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label=r'$\eta = 0.001 $')
plt.plot(epochs, data1, label=r'$\eta = 0.005 $')
plt.plot(epochs, data2, label=r'$\eta = 0.01 $')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_LR.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
print('0.001', '0.005', '0.01', sep=' & ', end=' \\\\\n')
print(np.max(data0), np.max(data1), np.max(data2), sep=' & ', end=' \\\\\n')
# Out:
# 0.001 & 0.005 & 0.01 \\
# 0.318 & 0.737 & 0.899 \\

# %% [markdown]
# \begin{table}[]
#     \begin{tabular}{|c|c|c|c|c|c|c|}
#         \hline
#          Коэффициент~обучения~\eta & 0.001 & 0.005 & 0.01  \\ \hline
#          Точность                  & 0.318 & 0.737 & 0.899 \\ \hline
#     \end{tabular}
# \end{table}

# %% [markdown]
# \begin{table}[]
#     \begin{tabular}{|c|c|}
#         \hline
#          Коэффициент обучения $\eta$    & Точность  \\ \hline
#          0.001                          & 0.318     \\ \hline
#          0.005                          & 0.737     \\ \hline
#          0.01                           & 0.899     \\ \hline
#     \end{tabular}
# \end{table}

# %%
sp0 = f'2022-02-11_22-51-01_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 1e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp2 = f'2022-02-12_08-32-55_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 0.0001 Adagrad-tag-{tag}.csv'
sp3 = f'2022-02-12_08-35-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 0.0005 Adagrad-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)
fp2 = os.path.join(dir, sp2)
fp3 = os.path.join(dir, sp3)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)
data2 = np.around(np.loadtxt(fp2, delimiter=',', skiprows=1)[:, 2], decimals=3)
data3 = np.around(np.loadtxt(fp3, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label=r'$\lambda = 0.00001 $')
plt.plot(epochs, data1, label=r'$\lambda = 0.00005 $')
plt.plot(epochs, data2, label=r'$\lambda = 0.0001 $')
plt.plot(epochs, data3, label=r'$\lambda = 0.0005 $')

plt.grid(True)
plt.legend(loc='upper left')
# plt.legend(loc='lower right')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_WD.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# ~Despite 5e-5 was bigger, 1e-5 was chosen for other experiments.

# %%
print('\lambda = 0.00001,', np.max(data0))
print('\lambda = 0.00005,', np.max(data1))
print('\lambda = 0.0001,', np.max(data2))
print('\lambda = 0.0005,', np.max(data3))
# Out:
# \lambda = 0.00001, 0.899
# \lambda = 0.00005, 0.882
# \lambda = 0.0001, 0.877
# \lambda = 0.0005, 0.863

# %%
print('0.00001', '0.00005', '0.0001', '0.0005', sep=' & ', end=' \\\\\n')
print(np.max(data0), np.max(data1), np.max(data2), np.max(data3), sep=' & ', end=' \\\\\n')
# Out:
# 0.00001 & 0.00005 & 0.0001 & 0.0005 \\
# 0.899 & 0.882 & 0.877 & 0.863 \\

# %% [markdown]
# \begin{table}[]
#     \begin{tabular}{|c|c|c|c|c|c|c|}
#         \hline
#          Коэффициент \\ оптимизации~\lambda & 0.00001 & 0.00005 & 0.0001 & 0.0005 \\ \hline
#          Точность                           & 0.899   & 0.882   & 0.877  & 0.863 \\ \hline
#     \end{tabular}
# \end{table}

# %%
sp0 = f'2022-02-12_12-03-15_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adadelta-tag-{tag}.csv'
sp1 = f'2022-02-12_11-57-41_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 SGD-tag-{tag}.csv'
sp2 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp3 = f'2022-02-12_11-59-50_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adam-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)
fp2 = os.path.join(dir, sp2)
fp3 = os.path.join(dir, sp3)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)
data2 = np.around(np.loadtxt(fp2, delimiter=',', skiprows=1)[:, 2], decimals=3)
data3 = np.around(np.loadtxt(fp3, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label=r'$Adadelta$')
plt.plot(epochs, data1, label=r'$SGD$')
plt.plot(epochs, data2, label=r'$Adagrad$')
plt.plot(epochs, data3, label=r'$Adam$')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_Optimizer.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
print('Adadelta,', np.max(data0))
print('SGD,', np.max(data1))
print('Adagrad,', np.max(data2))
print('Adam,', np.max(data3))
# Out:
# Adadelta, 0.584
# SGD, 0.854
# Adagrad, 0.882
# Adam, 0.908

# %% [markdown]
# \begin{table}[]
# \begin{tabular}{|c|c|}
#     \hline
#     Метод~оптимизации & Точность \\ \hline
#     Adadelta  & 0.584 \\ \hline
#     SGD       & 0.854 \\ \hline
#     Adagrad   & 0.882 \\ \hline
#     Adam      & 0.908 \\ \hline
#     \end{tabular}
# \end{table}

# %%
sp0 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-12_23-03-54_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad NoLRRescale-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label='Rescale with 0.01')
plt.plot(epochs, data1, label='Rescale absent')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_LRRescale.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
print(np.max(data0), np.max(data1))
# Out:
# 0.882 0.924

# %% [markdown]
# $$
# \begin{table}[]
#     \begin{tabular}{|c|c|}
#         \hline
#         Вариант                      & Точность \\ \hline
#         Масштабирование, \psi = 0.01 & 0.882     \\ \hline
#         Без~масштабирования          & 0.924    \\ \hline
#     \end{tabular}
# \end{table}
# $$

# %%
sp0 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-12_23-06-52_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad BatchNorm ResNet-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label='Групповая нормализция')
plt.plot(epochs, data1, label='Нормализация по батчу')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_Normalization.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
sp0 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-12_23-10-27_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad CosineLRDecayMinLRRatio 0.01-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label='Fixed')
plt.plot(epochs, data1, label='Cosine')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_LRDecay.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
sp0 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-13_06-03-45_Train-3-1-Scratch-MNISTISEG-Train LR 0.02 WD 5e-05 Adagrad CumIters 2-tag-{tag}.csv'
sp2 = f'2022-02-13_06-07-35_Train-3-1-Scratch-MNISTISEG-Train LR 0.03 WD 5e-05 Adagrad CumIters 3-tag-{tag}.csv'
sp3 = f'2022-02-13_06-09-19_Train-3-1-Scratch-MNISTISEG-Train LR 0.05 WD 5e-05 Adagrad CumIters 5-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)
fp2 = os.path.join(dir, sp2)
fp3 = os.path.join(dir, sp3)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)
data2 = np.around(np.loadtxt(fp2, delimiter=',', skiprows=1)[:, 2], decimals=3)
data3 = np.around(np.loadtxt(fp3, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 0.95)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label='Итерации: 1')
plt.plot(epochs, data1, label='Итерации: 2')
plt.plot(epochs, data2, label='Итерации: 3')
plt.plot(epochs, data3, label='Итерации: 5')

plt.grid(True)
plt.legend(loc='upper left')
plt.tight_layout()
# plt.title(f'Experiments with different learning rates $\gamma$')
plt.savefig('MNISTISEG_N3_K1_Experiments_CumIters.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
print('Iterations', '1', '2', '3', '5', sep=' & ')
print('Value', np.max(data0), np.max(data1), np.max(data2), np.max(data3), sep=' & ')
# Out:
# Iterations & 1 & 2 & 3 & 5
# Value & 0.882 & 0.899 & 0.851 & 0.742

# %% [markdown]
# \begin{table}[]
#     \begin{tabular}{|c|c|c|c|c|}
#         \hline
#          Итерации & 1 & 2 & 3 & 5 \\ \hline
#          Точность & 0.882 & 0.899 & 0.851 & 0.742 \\ \hline
#     \end{tabular}
# \end{table}

# %%
sp0 = f'2022-02-12_08-34-33_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adagrad-tag-{tag}.csv'
sp1 = f'2022-02-13_09-31-27_Train-3-1-Scratch-MNISTISEG-Train LR 0.01 WD 5e-05 Adam Cosine0.01 NoLRRescale-tag-{tag}.csv'

fp0 = os.path.join(dir, sp0)
fp1 = os.path.join(dir, sp1)

# Wall time, Step, Value
data0 = np.around(np.loadtxt(fp0, delimiter=',', skiprows=1)[:, 2], decimals=3)
data1 = np.around(np.loadtxt(fp1, delimiter=',', skiprows=1)[:, 2], decimals=3)

fig = plt.figure(figsize=(5, 4), dpi=100, facecolor='white')

plt.ylabel('Точность обнаружения объектов')
accuracy = np.arange(11, dtype=np.int32) / 10
plt.yticks(accuracy)
plt.ylim(0.1, 1.05)

plt.xlabel('Эпоха')
epochs = np.arange(10, dtype=np.int32) + 1
plt.xticks(epochs)

plt.plot(epochs, data0, label='$Adagrad, \eta=0.01, \lambda=0.00005$')
plt.plot(epochs, data1, label='$Adam, \eta=0.01, \lambda=0.00005$ \n NoLRRescale Cos')

plt.grid(True)
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('MNISTISEG_N3_K1_Final.png', facecolor=fig.get_facecolor(), edgecolor='none', transparent=False)
plt.show()

# %%
print(np.max(data0), np.max(data1))
# Out:
# 0.882 0.955

# %% [markdown]
# $$
# \begin{table}[]
#     \begin{tabular}{|c|c|}
#         \hline
#         Model  & Точность \\ \hline
#         Worst  & 0.882    \\ \hline
#         Best   & 0.955    \\ \hline
#     \end{tabular}
# \end{table}
# $$
